# %%
import os
from pathlib import Path
import pandas as pd
from concurrent.futures import ProcessPoolExecutor
from concurrent.futures import ThreadPoolExecutor
# Out:
# C:\Users\wadia\AppData\Roaming\Python\Python311\site-packages\pandas\core\arrays\masked.py:61: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (

# %%
df_clientes = pd.read_csv('./data/01_raw/01_Tabla_de_Clientes.csv', sep=',', encoding='latin-1')
df_clientes.head()
# Out:
#    cliente_id  edad genero  region    zona tipo_cliente  es_digital  uso_app  \
# 0           1    59      F    Lima  urbano   recurrente           0     0.36
# 1           2    49      F  Centro  urbano        nuevo           0     0.68
# 2           3    35      F   Norte   rural   recurrente           1     0.09
# 3           4    63      F     Sur  urbano        nuevo           1     0.38
# 4           5    28      M    Lima  urbano        nuevo           1     0.87
#
#    uso_whatsapp  interaccion_digital_score  canal_whatsapp  canal_sms  \
# 0             1                         27               1          1
# 1             1                         67               1          1
# 2             1                         56               1          1
# 3             1                         43               1          1
# 4             1                         93               1          1
#
#    canal_llamada  canal_campo  score_riesgo  prob_default  \
# ...

# %%
df_creditos = pd.read_csv('./data/01_raw/02_Tabla_de_Crditos.csv', sep=',', encoding='latin-1')
df_creditos.head()
# Out:
#    credito_id  cliente_id  periodo fecha_corte      producto  saldo_inicial  \
# 0           1           1  2026-01  2026-01-31  microcredito        4076.98
# 1           1           1  2026-02  2026-02-28  microcredito        4076.98
# 2           1           1  2026-03  2026-03-31  microcredito        4076.98
# 3           2           2  2026-01  2026-01-31       negocio         901.40
# 4           2           2  2026-02  2026-02-28       negocio         901.40
#
#    cuota_mensual  saldo_restante  dias_mora tramo_mora estado_credito  \
# 0         281.25         3850.56         13      01-30        vigente
# 1         281.25         3552.88          0          0        vigente
# 2         281.25         3276.21          0          0        vigente
# 3          70.76          815.20          7      01-30        vigente
# 4          70.76          815.20         37      31-60        vigente
#
#    pago_realizado_mes  monto_pagado_mes  fecha_pago  prob_pago_7d_base  \
# ...

# %%
df_contactos = pd.read_csv('./data/01_raw/03_Tabla_contactos.csv', sep=';', encoding='latin-1')
df_contactos.head()
# Out:
#    contacto_id  cliente_id  credito_id fecha_contacto hora_contacto  \
# 0            1           1           1      7/01/2026      20:15:00
# 1            2           1           1     27/01/2026      16:00:00
# 2            3           1           1     10/02/2026      17:45:00
# 3            4           1           1     17/02/2026      19:15:00
# 4            5           1           1     18/02/2026      15:30:00
#
#        producto  dias_mora       tramo_mora  saldo_restante  cuota_mensual  \
# 0  microcredito          0                0         4076.98         281.25
# 1  microcredito          1  1/01/2030 00:00         4071.53         281.25
# 2  microcredito          0                0         4020.05         281.25
# 3  microcredito          0                0         4006.28         281.25
# 4  microcredito          0                0         4027.13         281.25
#
#    ...  costo_contacto  prob_pago_7d_post_contacto_modelada  \
# ...
